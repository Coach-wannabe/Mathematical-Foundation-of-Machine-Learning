# %% [markdown]
# #  ML MID Project

# %% [markdown]
# # Bike Sharing Dataset

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn

# %% [markdown]
# Reading csv file as df and getting info about the dataset

# %%
df = pd.read_csv('hour.csv')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# Total amount of rented bikes

# %%
fig = sns.boxplot(data=df,y="cnt", orient="v")
fig.set(title='Total rental bikes, including casual and registered')
# Out:
# [Text(0.5, 1.0, 'Total rental bikes, including casual and registered')]

# %% [markdown]
# Number of bikes rented by Month, casual and registered users

# %%
fig, axes = plt.subplots(nrows=2)
fig.subplots_adjust(hspace=1)
sns.barplot(data=df, x='mnth', y='casual', ax=axes[0], capsize=0.2)
axes[0].set(ylabel='Count', title='Amount of rented bikes by Casual users according Month')
sns.barplot(data=df, x='mnth', y='registered', ax=axes[1], capsize=0.2)
axes[1].set(ylabel='Count', title='Amount of rented bikes by Registerd users according Month')
# Out:
# [Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Amount of rented bikes by Registerd users according Month')]

# %% [markdown]
# Number of bikes rented by Weekday, casual and registered users

# %%
fig, axes = plt.subplots(nrows=2)
fig.subplots_adjust(hspace=1)
sns.barplot(data=df, x='weekday', y='casual', ax=axes[0], capsize=0.2)
axes[0].set(ylabel='Count', title='Amount of rented bikes by Casual users according Weekday')
sns.barplot(data=df, x='weekday', y='registered', ax=axes[1], capsize=0.2)
axes[1].set(ylabel='Count', title='Amount of rented bikes by Registerd users according Weekday')
# Out:
# [Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Amount of rented bikes by Registerd users according Weekday')]

# %% [markdown]
# During what time people tend to rent bikes

# %%
fig, axes = plt.subplots(nrows=2)
fig.subplots_adjust(hspace=1)
sns.barplot(data=df, x='hr', y='casual', ax=axes[0], capsize=0.2)
axes[0].set(ylabel='Count', title='Amount of rented bikes by Casual users according Hour')
sns.barplot(data=df, x='hr', y='registered', ax=axes[1], capsize=0.2)
axes[1].set(ylabel='Count', title='Amount of rented bikes by Registerd users according Hour')
# Out:
# [Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Amount of rented bikes by Registerd users according Hour')]

# %% [markdown]
# How Season affects amount of rented bikes

# %%
fig, axes = plt.subplots(nrows=2)
fig.subplots_adjust(hspace=1)
sns.barplot(data=df, x='season', y='casual', ax=axes[0], capsize=0.2)
axes[0].set(ylabel='Count', title='Amount of rented bikes by Casual users according Season')
sns.barplot(data=df, x='season', y='registered', ax=axes[1], capsize=0.2)
axes[1].set(ylabel='Count', title='Amount of rented bikes by Registerd users according Season')
# Out:
# [Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Amount of rented bikes by Registerd users according Season')]

# %% [markdown]
# How weather affects amount of rented bikes

# %%
fig, axes = plt.subplots(nrows=2)
fig.set_size_inches(15, 15)
fig.subplots_adjust(hspace=0.2)
sns.boxplot(data=df, x='weathersit', y='casual', ax=axes[0])
axes[0].set(ylabel='Count', title="Box Plot On Casual Across Weather Situations")
sns.barplot(data=df, x='weathersit', y='registered', ax=axes[1])
axes[1].set(ylabel='Count', title="Box Plot On Registered Across Weather Situations")

'''
1: Clear, Few clouds, Partly cloudy, Partly cloudy
2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
'''
# Out:
# '\n1: Clear, Few clouds, Partly cloudy, Partly cloudy\n2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist\n3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds\n4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog\n'

# %% [markdown]
# How weather affects amount of rented bikes as linear plot

# %%
fig, axes = plt.subplots(figsize=(20,8))
sns.pointplot(data=df, x='hr', y='cnt', hue='season', ax=axes)
axes.set(title='Amount of Rented bikes according to Season')

# 1:springer, 2:summer, 3:fall, 4:winter
# Out:
# [Text(0.5, 1.0, 'Amount of Rented bikes according to Season')]

# %% [markdown]
# What amount of rent bikes during holidays

# %%
fig, axes = plt.subplots(figsize=(15,9))
sns.barplot(data=df, x='holiday', y='cnt', ax=axes, capsize=0.2)
axes.set(title='Amount of biked rented according to Holiday')
# Out:
# [Text(0.5, 1.0, 'Amount of biked rented according to Holiday')]

# %% [markdown]
# What amount of rent bikes during holidays

# %%
fig, axes = plt.subplots(figsize=(15,9))
sns.barplot(data=df, x='workingday', y='cnt', ax=axes, capsize=0.2)
axes.set(title='Amount of biked rented according to Workingday')
# Out:
# [Text(0.5, 1.0, 'Amount of biked rented according to Workingday')]

# %% [markdown]
# How temperature affect bike rent amount, line model and boxmodel

# %%
df.groupby('temp').mean()['cnt'].plot()
# Out:
# <AxesSubplot:xlabel='temp'>

# %%
sns.set(font_scale=2)
fig, axes = plt.subplots(nrows=1)
fig.set_size_inches(30, 10)
fig = sns.boxplot(data=df, y="cnt", x="temp",orient="v")
fig.set(xlabel='Temperature', ylabel='Amount of rented bikes', 
        title="Box Plot On Count Across Temperature")
fig.set_xticklabels(fig.get_xticklabels(), rotation=45, ha="right")
# Out:
# [Text(0, 0, '0.02'),
#  Text(1, 0, '0.04'),
#  Text(2, 0, '0.06'),
#  Text(3, 0, '0.08'),
#  Text(4, 0, '0.1'),
#  Text(5, 0, '0.12'),
#  Text(6, 0, '0.14'),
#  Text(7, 0, '0.16'),
#  Text(8, 0, '0.18'),
#  Text(9, 0, '0.2'),
#  Text(10, 0, '0.22'),
#  Text(11, 0, '0.24'),
#  Text(12, 0, '0.26'),
#  Text(13, 0, '0.28'),
#  Text(14, 0, '0.3'),
#  Text(15, 0, '0.32'),
#  Text(16, 0, '0.34'),
#  Text(17, 0, '0.36'),
#  Text(18, 0, '0.38'),
#  Text(19, 0, '0.4'),
#  Text(20, 0, '0.42'),
#  Text(21, 0, '0.44'),
#  Text(22, 0, '0.46'),
#  Text(23, 0, '0.48'),
#  Text(24, 0, '0.5'),
#  Text(25, 0, '0.52'),
#  Text(26, 0, '0.54'),
#  Text(27, 0, '0.56'),
#  Text(28, 0, '0.58'),
#  Text(29, 0, '0.6'),
#  Text(30, 0, '0.62'),
#  Text(31, 0, '0.64'),
#  Text(32, 0, '0.66'),
#  Text(33, 0, '0.68'),
#  Text(34, 0, '0.7'),
#  Text(35, 0, '0.72'),
#  Text(36, 0, '0.74'),
#  Text(37, 0, '0.76'),
#  Text(38, 0, '0.78'),
#  Text(39, 0, '0.8'),
#  Text(40, 0, '0.82'),
#  Text(41, 0, '0.84'),
# ...

# %% [markdown]
# Grouping all number columns

# %%
num_columns = list(df.select_dtypes(['int64', 'float64']).columns)
num_features = pd.Index(num_columns)
num_features
# Out:
# Index(['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# Relationship between number columns

# %%
for col in num_features:
    plt.figure(figsize=(10,6))
    sns.histplot(x=df[col])
    plt.xlabel(col)

# %%
for col in num_features:
    plt.figure(figsize=(10,6))
    sns.histplot(x=df[col], kde=True, stat="density")
    plt.xlabel(col)

# %% [markdown]
# Number columns and total amount of rented bikes

# %%
for col in num_features:
    fig, axes = plt.subplots(figsize=(10,6))
    sns.regplot(x=df[col], y=df['cnt'], line_kws={'color':'red'})

# %%
plt.figure(figsize=(10,6))
plt.xlabel('cnt')
plt.ylabel('density')
ax = sns.distplot(df['cnt'], hist=True, color='y')
ax.axvline(df['cnt'].mean(), color='magenta', linestyle='dashed', linewidth=2)
ax.axvline(df['cnt'].median(), color='blue', linestyle='dashed', linewidth=2)
# Out:
# C:\Users\adile\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
plt.xlabel('cnt')
plt.ylabel('density')

ax = sns.distplot(np.sqrt(df['cnt']), color='y')
ax.axvline(np.sqrt(df['cnt']).mean(), color='magenta', linestyle='dashed', linewidth=2)
ax.axvline(np.sqrt(df['cnt']).median(), color='blue', linestyle='dashed', linewidth=2)
# Out:
# C:\Users\adile\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Getting rid of outliers

# %%
plt.ylabel('cnt')
sns.boxplot(x=np.sqrt(df['cnt']))
# Out:
# <AxesSubplot:xlabel='cnt', ylabel='cnt'>

# %% [markdown]
# Correlation

# %%
df.corr()
# Out:
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# weathersit -0.014198 -0.014524 -0.019157  0.005400 -0.020203 -0.017036
# temp        0.136178  0.312025  0.040913  0.201691  0.137603 -0.027340
# atemp       0.137615  0.319380  0.039222  0.208096  0.133750 -0.030973
# hum         0.009577  0.150625 -0.083546  0.164411 -0.276498 -0.010588
# ...

# %%
plt.figure(figsize=(30,15))
correlation = df.corr()
m = np.triu(np.ones_like(correlation, dtype=bool))
sns.heatmap((correlation), mask=m, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Linear Regression

# %%
copy_df = df.drop(['atemp', 'dteday', 'instant'], axis=1)

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      17379 non-null  int64
#  1   yr          17379 non-null  int64
#  2   mnth        17379 non-null  int64
#  3   hr          17379 non-null  int64
#  4   holiday     17379 non-null  int64
#  5   weekday     17379 non-null  int64
#  6   workingday  17379 non-null  int64
#  7   weathersit  17379 non-null  int64
#  8   temp        17379 non-null  float64
#  9   hum         17379 non-null  float64
#  10  windspeed   17379 non-null  float64
#  11  casual      17379 non-null  int64
#  12  registered  17379 non-null  int64
#  13  cnt         17379 non-null  int64
# dtypes: float64(3), int64(11)
# memory usage: 1.9 MB

# %%
X = copy_df.drop(columns=['cnt'], axis=1)
Y = np.sqrt(df['cnt'])

# %%
X.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   hum  \
# 0       1   0     1   0        0        6           0           1  0.24  0.81
# 1       1   0     1   1        0        6           0           1  0.22  0.80
# 2       1   0     1   2        0        6           0           1  0.22  0.80
# 3       1   0     1   3        0        6           0           1  0.24  0.75
# 4       1   0     1   4        0        6           0           1  0.24  0.75
#
#    windspeed  casual  registered
# 0        0.0       3          13
# 1        0.0       8          32
# 2        0.0       5          27
# 3        0.0       3          10
# 4        0.0       0           1

# %%
Y.head()
# Out:
# 0    4.000000
# 1    6.324555
# 2    5.656854
# 3    3.605551
# 4    1.000000
# Name: cnt, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (13034, 13)
# (4345, 13)

# %%
copy_df.describe().columns
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'registered',
#        'cnt'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression().fit(X_train, Y_train)
regression.score(X_train, Y_train)
# Out:
# 0.9422362979676757

# %%
regression.coef_
# Out:
# array([ 0.11548965, -0.04176724, -0.00148981,  0.13099888, -0.16938413,
#         0.01737172, -0.11095207,  0.06587466,  1.40962129, -1.15457073,
#         0.19905073,  0.03175983,  0.0327327 ])

# %%
Y_pred_train = regression.predict(X_train)
Y_pred_test = regression.predict(X_test)

# %%
sns.scatterplot(Y_test, Y_pred_test)
# Out:
# C:\Users\adile\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cnt'>

# %%
from sklearn import metrics

MAE = metrics.mean_absolute_error(Y_train, Y_pred_train)
print("MAE:", MAE)

MSE = metrics.mean_squared_error((Y_train), (Y_pred_train))
print("MSE:", MSE)

RMSE = np.sqrt(MSE)
print("RMSE:", RMSE)

from sklearn.metrics import r2_score
R2 = r2_score(Y_train, Y_pred_train)
print("R2:", R2)

adjusted_r2 = (1-(1-r2_score(Y_train, Y_pred_train)) * ((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
print("Adjusted R2:", 1-(1-r2_score(Y_train, Y_pred_train))*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
# Out:
# MAE: 1.295251585832273
# MSE: 2.60055342623782
# RMSE: 1.6126231507199131
# R2: 0.9422362979676757
# Adjusted R2: 0.9420629135007119
